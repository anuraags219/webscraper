# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.magicbricks.com/property-for-rent/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Service-Apartment&Locality=Hinjewadi&cityName=Pune')

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
p = soup.find_all(itemtype='//schema.org/Apartment')

# %%
print(p)
# Out:
# [<div itemscope="" itemtype="//schema.org/Apartment">
# <meta content=" 2 BHK Apartment for Rent in High Mount Phase 2, Hinjewadi 960 sqft" itemprop="name">
# <meta content="2 Bath,Unfurnished,3 floor,North - East facing We charge only flat service fees for an apartment in Pune. Professional Property Management. Multiple direct options available. 2bhk apartment available in High Mont. It is  a resort theme based project, exactly in the lap of nature." itemprop="description">
# <meta content="/propertyDetails/2-BHK-960-Sq-ft-Multistorey-Apartment-FOR-Rent-Hinjewadi-in-Pune&amp;id=4d423531323032303830" itemprop="url">
# <div itemprop="address" itemscope="" itemtype="//schema.org/PostalAddress">
# <meta content="Hinjewadi" itemprop="addressLocality">
# <input content="IN" itemprop="addressCountry" type="hidden">
# </input></meta></div>
# <meta content="2" itemprop="numberOfRooms">
# <meta content="960 FTK " itemprop="floorSize">
# ...

# %%
results = soup.find_all('div', attrs={'itemtype':'//schema.org/Apartment'})

# %%
records = []  
for result in results:  
    #name = result.find('div', attrs={'class':'name'}).text # result not results
    #records.append(name)
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
    break
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
print(result)
# Out:
# <div itemscope="" itemtype="//schema.org/Apartment">
# <meta content=" 2 BHK Apartment for Rent in High Mount Phase 2, Hinjewadi 960 sqft" itemprop="name">
# <meta content="2 Bath,Unfurnished,3 floor,North - East facing We charge only flat service fees for an apartment in Pune. Professional Property Management. Multiple direct options available. 2bhk apartment available in High Mont. It is  a resort theme based project, exactly in the lap of nature." itemprop="description">
# <meta content="/propertyDetails/2-BHK-960-Sq-ft-Multistorey-Apartment-FOR-Rent-Hinjewadi-in-Pune&amp;id=4d423531323032303830" itemprop="url">
# <div itemprop="address" itemscope="" itemtype="//schema.org/PostalAddress">
# <meta content="Hinjewadi" itemprop="addressLocality">
# <input content="IN" itemprop="addressCountry" type="hidden">
# </input></meta></div>
# <meta content="2" itemprop="numberOfRooms">
# <meta content="960 FTK " itemprop="floorSize">
# </meta></meta></meta></meta></meta></div>

# %%
name = result.find('meta', attrs={'itemprop':'name'}) # result not results
print(name)
# Out:
# <meta content=" 2 BHK Apartment for Rent in High Mount Phase 2, Hinjewadi 960 sqft" itemprop="name">
# <meta content="2 Bath,Unfurnished,3 floor,North - East facing We charge only flat service fees for an apartment in Pune. Professional Property Management. Multiple direct options available. 2bhk apartment available in High Mont. It is  a resort theme based project, exactly in the lap of nature." itemprop="description">
# <meta content="/propertyDetails/2-BHK-960-Sq-ft-Multistorey-Apartment-FOR-Rent-Hinjewadi-in-Pune&amp;id=4d423531323032303830" itemprop="url">
# <div itemprop="address" itemscope="" itemtype="//schema.org/PostalAddress">
# <meta content="Hinjewadi" itemprop="addressLocality">
# <input content="IN" itemprop="addressCountry" type="hidden">
# </input></meta></div>
# <meta content="2" itemprop="numberOfRooms">
# <meta content="960 FTK " itemprop="floorSize">
# </meta></meta></meta></meta></meta>

# %%
if('numerOfRooms' in result):
    print('d')
